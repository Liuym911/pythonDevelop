# %%
#双下划线开头双下划线结尾的是魔法函数
#魔法函数只能使用python给我们提供等魔法函数


# python中的for循环其实是拿到一个迭代器的,但是我们的类其实没迭代器,想拿到迭代器,应该要实现__iter__ 这个魔法函数才能拿到迭代器
# 但是python 语法会做一些优化，如果拿不到迭代器,会看类里面有没有__getitem__这个方法
# 会一次一次的直到吧数据取完

class Company(object):
    def __init__(self, employee_list):
        self.employee = employee_list
    #
    # def __getitem__(self, item):
    #     return self.employee[item]

    def __len__(self):
        return len(self.employee)



company = Company(["tom", "bob", "jane"])


# company1= company[:2]
#
# print(len(company))
#
# for em in company1:
#     print(em)
